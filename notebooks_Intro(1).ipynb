# %% [markdown]
# my data is about deth in iraq

# %%
import pandas as pd
import numpy as np

# %%
sama= pd.read_csv('Deathsonly.csv')

# %%
sama
# Out:
#                                                                                     A MITT AND MNF-W JUMP CP : 2 CF KIA 2 CF WIA 8 UE DET  \
# D5C961BD-BC20-F20A-21D0456BBB9EC4F7 25/11/2008 17:40 Explosive Hazard IED Explosion  (EXPLOSIVE HAZARD) IED EXPLOSION RPT  (Improvi...
# D4CE0A6D-B8CA-025C-051E8314A01586FE 25/11/2008 18:00 Enemy Action     Direct Fire    (ENEMY ACTION) DIRECT FIRE RPT  (Small Arms) 2...
# DB5D7A44-B797-C0F6-5CAE18594E5A3F51 26/11/2008 12:00 Other            Other                    (OTHER) OTHER RPT   BOC OPS : 3 CIV KIA
# DB84D3FF-965C-7D14-DF80C15FDEA674F5 26/11/2008 12:00 Criminal Event   Murder         (CRIMINAL EVENT) MURDER RPT   ANBAR OPS : 3 CI...
# DB5200C4-916D-2CA8-2C2ADF4275A0B9F9 26/11/2008 12:20 Criminal Event   Murder         (CRIMINAL EVENT) MURDER RPT   BAGHDAD POLICE O...
# ...                                                                                                                                ...
# ...
